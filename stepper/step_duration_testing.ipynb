# %%
# %load_ext autoreload

# %%
# %autoreload 2
from driver import StepperDriver
import time
# %matplotlib notebook
import matplotlib.pyplot as plt

import ipywidgets as widgets
import numpy as np

# %%
stepper_driver = StepperDriver()

S_tgt = 0.5
V_max = 1.5
jerk = 200
step_durations = stepper_driver.calc_step_durations(S_tgt=S_tgt, V_max=V_max, J=jerk, microsteps_per_rev=200*8)

data = np.array(step_durations)
plt.figure()
plt.plot(data[:,0])
plt.grid();
# plt.xlim(580,590)

plt.figure()
# plt.plot(data[:,1], label='t')
plt.plot(data[:,2], label='t+t0')
plt.plot(data[:,3], label='last')
plt.grid(); plt.legend()
# plt.xlim(580,590)
# plt.ylim(0.33, 0.34)
# Out:
# [0.08660254037844387, 200, None]
# [0.08660254037844387, -200, None]
# [0.16012825257644556, 0, 1.5000000000000002]
# [0.08660254037844387, -200, None]
# [0.08660254037844387, 200, None]
# 0
# 34
# 200
# 585
# 752
# <img src="data:image/png;base64,..." width="639.999990463257">
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
plot_widget = widgets.Image(
)
plot_widget
# Out:
# Image(value=b'')

# %%
stepper_driver = StepperDriver()

microstep_resolution = 8
max_speed = 1.5
jerk = 200

revs = 1
step_durations = stepper_driver.move(
    revs, 
    direction=1, 
    microstep_resolution=microstep_resolution, 
    rev_per_sec=max_speed,
    max_jerk=jerk,
    monitor_widget=plot_widget,
)

time.sleep(0.2)

step_durations = stepper_driver.move(
    revs, 
    direction=0, 
    microstep_resolution=microstep_resolution, 
    rev_per_sec=max_speed,
    max_jerk=jerk,
    monitor_widget=plot_widget,
)

# %%
S_tgt = 0.1
V_max = 1.5
jerk = 200
step_durations = stepper_driver.calc_step_durations(S_tgt=S_tgt, V_max=V_max, J=jerk, microsteps_per_rev=8)
step_durations
# Out:
# 0.17320508075688773 0.1299038105676658
# [[0.06299605249474366, 200, None], [0.06299605249474366, -200, None], [0.0, 0, 0.7937005259840998], [0.06299605249474366, -200, None], [0.06299605249474366, 200, None]]
# []
